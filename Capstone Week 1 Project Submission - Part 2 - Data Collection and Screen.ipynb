# %% [markdown]
# # Capstone Project - Relocation from New York City to Toronto
# ### For Applied Data Science Capstone Course by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem Description](#introduction)
# * [Data Collection](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem Description <a name="introduction"></a>

# %% [markdown]
# This project is designed to resolve the following assumed business case:
#
# A US business manager who is working for a large financial company and also living in Manhatten, New York city. Recently his company has asked him to relocate from New York to Toronto Canada to lead the efforts to set up a branch business there. He needs to decide where to set up the business office in Toronto. He also needs to select a new residential location for his family, preferrablely in a similar favorable location to his home in Manhatten in New York.
#
# This business manager approached a specialized service company to help him to evaluate the location options in Toronto for both business office and his family home in Toronto. After signing the service contract, this service company starts to work on this project. This project could involve the following aspects:
#
# 1. First to evaluate and to understand the preferred characteristics from this US business manager on his current business office and family home in Manhatten in New York.
# 2. Second to collect and to evaluate information related to Toronto.
# 3. Compare the similarities and differences between New York and Toronto.
# 4. Based on US manager's preferred selection criterias to recommend location options on new business office and residential home in Toronto.
#
# For each of above project aspects, we will conduct relevent data collection and data analysis to provide quantitative asscessment. We will work the following data science project steps:
# 1. Collect neighborhood information between New York and Toronto.
# 2. Collect relevant venue information that could be required to compare between New York and Toronto.
# 3. Analyze the collected data to compare the similarities and differences between New York and Toronto.
# 4. Based on US business manager's proposed location selection preference criterias to recommend location options for both busines office and family home in Toronto.

# %% [markdown]
# ## Data Collection <a name="data"></a>

# %% [markdown]
# #### Based on the above busienss problem descriptinon, we will collect the following data sets:
# 1. Neighborhood and venue information for New York city, including:
#     (1) Neighborhood information for New York city.
#     (2) Neighborhood information for Manhatten, New York.
#     (3) Venues around existing business office in Manhatten, New York city.
#     (4) Venues around existing family home locations in Manhatten, New York city.
#
#
# 2. Neighborhood and venue information for Toronto, including:
#     (1) Neighborhood information for Toronto.
#     (2) Neighborhood information for Toronto financial central location.
#     (3) Venue information for Toronto financial central location.

# %% [markdown]
# ## 1. Collect neighborhood and venue Information for New York city

# %% [markdown]
# ### (1) Collect neighborhood Information for New York city
#
# To get New York neighborhood information, we first download existing dataset newyork_data online. We convert the online dataset into pandas dataframe. The neighborhood information is then visualized on New York map.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# First to input the existing dataset from web site

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %% [markdown]
# The next is to transform the data into a pandas dataframe.

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %% [markdown]
# Use geopy library to get the latitude and longitude values of New York City

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_newyork = neighborhoods
df_newyork.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %% [markdown]
# ### (2) Collect neighborhood Information for Manhatten, New York
#
# The Manhatten neighborhood data is a subset from New York neighborhood dataset. The data is visualized on a map.

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %%
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 40.7900869, -73.9598295.

# %%
# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### (3) Collect venues around existing business office in Manhatten, New York city.
#
# Assume that the business office address is 100 Wall St New York, near New York Stock Exchange location.

# %% [markdown]
# #### We are using Foursqure API to collect venue information

# %%
CLIENT_ID = '0D33T0AVFXWBBXCZDHJ2IA32T5GG5IK1J5GYXBAIP14Z4KRF' # your Foursquare ID
CLIENT_SECRET = '0L2NKXGCDXVV3HLBJDOJDSNIOPCOODUIZOQQECZ4DC5F2ZIQ' # your Foursquare Secret
VERSION = '20180604'

# %%
address = '100 Wall St, New York, NY'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7052203 -74.006799602293

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=0D33T0AVFXWBBXCZDHJ2IA32T5GG5IK1J5GYXBAIP14Z4KRF&client_secret=0L2NKXGCDXVV3HLBJDOJDSNIOPCOODUIZOQQECZ4DC5F2ZIQ&v=20180604&ll=40.7052203,-74.006799602293&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d334edde706550025124a61'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Financial District',
#   'headerFullLocation': 'Financial District, New York',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 197,
#   'suggestedBounds': {'ne': {'lat': 40.7097203045, 'lng': -74.00087459097615},
#    'sw': {'lat': 40.7007202955, 'lng': -74.01272461360985}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c883f65f4b525002c0bf2ca',
#        'name': 'Crown Shy',
#        'location': {'address': '70 Pine St',
#         'lat': 40.70618693053086,
#         'lng': -74.00749011603791,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70618693053086,
#           'lng': -74.00749011603791}],
#         'distance': 122,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['70 Pine St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c883f65f4b525002c0bf2ca-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '577c4a4a498e2c214c8f57e1',
#        'name': 'sweetgreen',
#        'location': {'address': '67 Wall St',
#         'lat': 40.705586,
#         'lng': -74.008382,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.705586,
#           'lng': -74.008382}],
#         'distance': 139,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['67 Wall St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1033829',
#         'url': 'https://www.seamless.com/menu/sweetgreen-67-wall-st-new-york/1033829?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1033829',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-577c4a4a498e2c214c8f57e1-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '574456e5498e39c73d234da1',
#        'name': 'Black Fox Coffee Co.',
#        'location': {'address': '70 Pine St',
#         'lat': 40.70657289005604,
#         'lng': -74.00815534778381,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70657289005604,
#           'lng': -74.00815534778381}],
#         'distance': 189,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['70 Pine St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-574456e5498e39c73d234da1-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '561a8cd8498ed81f4384d0aa',
#        'name': 'La Colombe Torrefaction',
#        'location': {'address': '67 Wall St',
#         'lat': 40.705898810664266,
#         'lng': -74.00842129724238,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.705898810664266,
#           'lng': -74.00842129724238}],
#         'distance': 156,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['67 Wall St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '155078060'}},
#       'referralId': 'e-0-561a8cd8498ed81f4384d0aa-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1bc07fa809bd1305bff584',
#        'name': 'East River Esplanade',
#        'location': {'address': 'South St',
#         'crossStreet': 'From Pier 11 to Pier 17',
#         'lat': 40.70484714530104,
#         'lng': -74.00459289550781,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70484714530104,
#           'lng': -74.00459289550781}],
#         'distance': 190,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['South St (From Pier 11 to Pier 17)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a25',
#          'name': 'Pedestrian Plaza',
#          'pluralName': 'Pedestrian Plazas',
#          'shortName': 'Pedestrian Street/Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e1bc07fa809bd1305bff584-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5459292b498e72e209527504',
#        'name': 'SoulCycle FiDi',
#        'location': {'address': '101 Maiden Ln',
#         'crossStreet': 'btwn Gold & Pearl St',
#         'lat': 40.70690416548221,
#         'lng': -74.0067171192261,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70690416548221,
#           'lng': -74.0067171192261}],
#         'distance': 187,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['101 Maiden Ln (btwn Gold & Pearl St)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b49',
#          'name': 'Cycle Studio',
#          'pluralName': 'Cycle Studios',
#          'shortName': 'Cycle Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5459292b498e72e209527504-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7ef289f964a52058f21fe3',
#        'name': 'Dig Inn',
#        'location': {'address': '80 Pine St',
#         'crossStreet': 'at Pearl St',
#         'lat': 40.706105728669954,
#         'lng': -74.0072902754321,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.706105728669954,
#           'lng': -74.0072902754321}],
#         'distance': 106,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['80 Pine St (at Pearl St)',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a7ef289f964a52058f21fe3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58ab3a6a53f5bb4b6b267ad1',
#        'name': 'City Acres Market',
#        'location': {'address': '70 Pine St',
#         'lat': 40.7062610487484,
#         'lng': -74.0077295435263,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7062610487484,
#           'lng': -74.0077295435263}],
#         'distance': 139,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['70 Pine St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58ab3a6a53f5bb4b6b267ad1-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bba18d11261d13adc36ea98',
#        'name': "Adel's best #1 Halal Food Cart",
#        'location': {'address': 'Maiden Lane & Front street',
#         'crossStreet': 'Maiden Lane & Front street',
#         'lat': 40.70560923100874,
#         'lng': -74.00559949094632,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70560923100874,
#           'lng': -74.00559949094632}],
#         'distance': 110,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Maiden Lane & Front street (Maiden Lane & Front street)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10b941735',
#          'name': 'Falafel Restaurant',
#          'pluralName': 'Falafel Restaurants',
#          'shortName': 'Falafel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bba18d11261d13adc36ea98-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58fa6663c530932d7a53ec1e',
#        'name': 'Westville Wall Street',
#        'location': {'address': '110 Wall St',
#         'lat': 40.70476029018973,
#         'lng': -74.00673200859217,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70476029018973,
#           'lng': -74.00673200859217}],
#         'distance': 51,
#         'postalCode': '10005',
#         'cc': 'US',
#         'neighborhood': 'Financial District',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['110 Wall St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '425978',
#         'url': 'https://www.seamless.com/menu/westville-wall-street-110-wall-st-new-york/425978?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=425978',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58fa6663c530932d7a53ec1e-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49b7aefcf964a5202d531fe3',
#        'name': 'Cipriani Wall Street',
#        'location': {'address': '55 Wall St',
#         'crossStreet': 'btwn William & Hanover St',
#         'lat': 40.7060378788768,
#         'lng': -74.00926866051051,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7060378788768,
#           'lng': -74.00926866051051}],
#         'distance': 227,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['55 Wall St (btwn William & Hanover St)',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d171941735',
#          'name': 'Event Space',
#          'pluralName': 'Event Spaces',
#          'shortName': 'Event Space',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '406087',
#         'url': 'https://www.seamless.com/menu/cipriani-55-wall-st-new-york/406087?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=406087',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49b7aefcf964a5202d531fe3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '521b898a8bbdce5bf8e95c58',
#        'name': 'Complete Body',
#        'location': {'address': '10 Hanover Sq',
#         'crossStreet': 'Hanover Square, between Pearl St and Water St',
#         'lat': 40.70434084081434,
#         'lng': -74.00916057926591,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70434084081434,
#           'lng': -74.00916057926591}],
#         'distance': 221,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['10 Hanover Sq (Hanover Square, between Pearl St and Water St)',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-521b898a8bbdce5bf8e95c58-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae05d51f964a520d97e21e3',
#        'name': 'Minas Shoe Repair',
#        'location': {'address': '67 Wall St',
#         'crossStreet': 'at Hanover St.',
#         'lat': 40.70593187465497,
#         'lng': -74.00843066267862,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70593187465497,
#           'lng': -74.00843066267862}],
#         'distance': 158,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['67 Wall St (at Hanover St.)',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d107951735',
#          'name': 'Shoe Store',
#          'pluralName': 'Shoe Stores',
#          'shortName': 'Shoes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae05d51f964a520d97e21e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1b13ddf964a520bbf723e3',
#        'name': 'Andaz Wall Street - A Concept By Hyatt',
#        'location': {'address': '75 Wall St',
#         'lat': 40.70509963058996,
#         'lng': -74.00786819507917,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70509963058996,
#           'lng': -74.00786819507917}],
#         'distance': 91,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['75 Wall St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1b13ddf964a520bbf723e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a3bbd58f964a520b7a01fe3',
#        'name': 'Elevated Acre',
#        'location': {'address': '55 Water St',
#         'lat': 40.70326926503271,
#         'lng': -74.00871276855469,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70326926503271,
#           'lng': -74.00871276855469}],
#         'distance': 270,
#         'postalCode': '10041',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['55 Water St',
#          'New York, NY 10041',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a25',
#          'name': 'Pedestrian Plaza',
#          'pluralName': 'Pedestrian Plazas',
#          'shortName': 'Pedestrian Street/Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a3bbd58f964a520b7a01fe3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6ea3946af58cfa37d18c17',
#        'name': 'Fetch Club',
#        'location': {'address': '85 South St',
#         'crossStreet': 'Fletcher and John',
#         'lat': 40.70580271279971,
#         'lng': -74.004135910737,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70580271279971,
#           'lng': -74.004135910737}],
#         'distance': 233,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['85 South St (Fletcher and John)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d100951735',
#          'name': 'Pet Store',
#          'pluralName': 'Pet Stores',
#          'shortName': 'Pet Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '61767340'}},
#       'referralId': 'e-0-4c6ea3946af58cfa37d18c17-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5824bf8a79b37275760bb458',
#        'name': 'Bluestone Lane',
#        'location': {'address': '90 Water Street',
#         'crossStreet': 'at Gouvereur La',
#         'lat': 40.704599078972464,
#         'lng': -74.00874763727188,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.704599078972464,
#           'lng': -74.00874763727188}],
#         'distance': 178,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['90 Water Street (at Gouvereur La)',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5824bf8a79b37275760bb458-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5587da4f498e9d88e373b269',
#        'name': 'Pure Barre Financial District',
#        'location': {'address': '80 Pine St Lbby 1',
#         'lat': 40.70657626896267,
#         'lng': -74.00696972019936,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70657626896267,
#           'lng': -74.00696972019936}],
#         'distance': 151,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['80 Pine St Lbby 1',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5587da4f498e9d88e373b269-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '545d602b498e50ade1906a6e',
#        'name': 'El Luchador',
#        'location': {'address': '87 South St',
#         'crossStreet': 'at John St',
#         'lat': 40.705817,
#         'lng': -74.004063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.705817,
#           'lng': -74.004063}],
#         'distance': 240,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['87 South St (at John St)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '105483228'}},
#       'referralId': 'e-0-545d602b498e50ade1906a6e-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ab27744f964a520486b20e3',
#        'name': "Harry's Cafe and Steak",
#        'location': {'address': '1 Hanover Sq',
#         'lat': 40.704558487365915,
#         'lng': -74.00974598616519,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.704558487365915,
#           'lng': -74.00974598616519}],
#         'distance': 259,
#         'postalCode': '10004',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1 Hanover Sq',
#          'New York, NY 10004',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '84168',
#         'url': 'https://www.seamless.com/menu/harrys-cafe--steak-1-hanover-sq-new-york/84168?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=84168',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '93014239'}},
#       'referralId': 'e-0-4ab27744f964a520486b20e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5802493e38faed5f8e5e75b4',
#        'name': 'Pressed Juicery',
#        'location': {'address': '100 Maiden Ln',
#         'lat': 40.70697519746518,
#         'lng': -74.0073128834324,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70697519746518,
#           'lng': -74.0073128834324}],
#         'distance': 200,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['100 Maiden Ln',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '383485',
#         'url': 'https://www.seamless.com/menu/pressed-juicery-100-maiden-ln-new-york/383485?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=383485',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5802493e38faed5f8e5e75b4-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59bfd77cda2e005751c2b9b3',
#        'name': 'JOE & THE JUICE',
#        'location': {'address': '67 Wall Street',
#         'crossStreet': 'at Pearl St',
#         'lat': 40.70556958853848,
#         'lng': -74.00816003352689,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70556958853848,
#           'lng': -74.00816003352689}],
#         'distance': 121,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['67 Wall Street (at Pearl St)',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59bfd77cda2e005751c2b9b3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56276e9a498ea473acbc2391',
#        'name': 'ChaiseFitness',
#        'location': {'address': '180 Maiden Ln',
#         'lat': 40.70561376975429,
#         'lng': -74.00556387151113,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70561376975429,
#           'lng': -74.00556387151113}],
#         'distance': 113,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['180 Maiden Ln',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56276e9a498ea473acbc2391-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b82c540c97f28002c65fa73',
#        'name': 'Taim',
#        'location': {'address': '75 Maiden Ln',
#         'lat': 40.70772671818465,
#         'lng': -74.00826536952118,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70772671818465,
#           'lng': -74.00826536952118}],
#         'distance': 305,
#         'postalCode': '10038',
#         'cc': 'US',
#         'neighborhood': 'Financial District',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['75 Maiden Ln',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10b941735',
#          'name': 'Falafel Restaurant',
#          'pluralName': 'Falafel Restaurants',
#          'shortName': 'Falafel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '908713',
#         'url': 'https://www.seamless.com/menu/taim-75-maiden-ln-new-york/908713?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=908713',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b82c540c97f28002c65fa73-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51abad1c7dd28f673d21bbf4',
#        'name': 'Trading Post',
#        'location': {'address': '170 John St',
#         'crossStreet': 'btwn Front St & South St',
#         'lat': 40.70593989125792,
#         'lng': -74.00398254337208,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70593989125792,
#           'lng': -74.00398254337208}],
#         'distance': 250,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['170 John St (btwn Front St & South St)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '298601',
#         'url': 'https://www.seamless.com/menu/trading-post-170-john-st-new-york/298601?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=298601',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '58051921'}},
#       'referralId': 'e-0-51abad1c7dd28f673d21bbf4-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '566c66b838fa37fd4827c98e',
#        'name': 'Q&A Residential Hotel',
#        'location': {'address': '70 Pine St',
#         'lat': 40.706555625770974,
#         'lng': -74.00814263889156,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.706555625770974,
#           'lng': -74.00814263889156}],
#         'distance': 186,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['70 Pine St', 'New York, NY', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-566c66b838fa37fd4827c98e-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5187b7ca498e26e78cc393a9',
#        'name': 'Roti Modern Mediterranean',
#        'location': {'address': '100 Maiden Ln',
#         'crossStreet': 'Pearl',
#         'lat': 40.70652770789553,
#         'lng': -74.00713526836626,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70652770789553,
#           'lng': -74.00713526836626}],
#         'distance': 148,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['100 Maiden Ln (Pearl)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '306861',
#         'url': 'https://www.seamless.com/menu/roti-modern-mediterranean-100-maiden-lane-new-york/306861?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=306861',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5187b7ca498e26e78cc393a9-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eef9dfe6c25c7f9d47c80b4',
#        'name': 'Pier 15',
#        'location': {'address': 'South St',
#         'crossStreet': 'at Fletcher St',
#         'lat': 40.7047418983676,
#         'lng': -74.0034073830095,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7047418983676,
#           'lng': -74.0034073830095}],
#         'distance': 291,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['South St (at Fletcher St)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4e74f6cabd41c4836eac4c31',
#          'name': 'Pier',
#          'pluralName': 'Piers',
#          'shortName': 'Piers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/ferry_pier_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eef9dfe6c25c7f9d47c80b4-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '3fd66200f964a520daf11ee3',
#        'name': 'South Street Seaport',
#        'location': {'address': 'South St',
#         'crossStreet': 'Pier 17',
#         'lat': 40.70637456835184,
#         'lng': -74.00349346101993,
#         'distance': 307,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['South St (Pier 17)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0941735',
#          'name': 'Harbor / Marina',
#          'pluralName': 'Harbors / Marinas',
#          'shortName': 'Harbor / Marina',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/harbor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '59071427'}},
#       'referralId': 'e-0-3fd66200f964a520daf11ee3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4e02acdb2c20a1be3bbc73',
#        'name': 'Imagination Playground at Burling Slip',
#        'location': {'address': 'John St (at South Street Seaport)',
#         'crossStreet': 'btw Front & South Sts',
#         'lat': 40.7062325343663,
#         'lng': -74.00421519438541,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7062325343663,
#           'lng': -74.00421519438541}],
#         'distance': 245,
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['John St (at South Street Seaport) (btw Front & South Sts)',
#          'New York, NY',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c4e02acdb2c20a1be3bbc73-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bcdfcde6f0aa2002cf48436',
#        'name': 'Blue Park Kitchen',
#        'location': {'address': '70 Pine St',
#         'lat': 40.70650307601242,
#         'lng': -74.00807663263792,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70650307601242,
#           'lng': -74.00807663263792}],
#         'distance': 178,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['70 Pine St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1075391',
#         'url': 'https://www.seamless.com/menu/blue-park-kitchen-70-pine-st-new-york/1075391?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1075391',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bcdfcde6f0aa2002cf48436-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e9c5e940aaf5f690f18825c',
#        'name': 'Dig Records',
#        'location': {'lat': 40.70498218375558,
#         'lng': -74.0060844577204,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70498218375558,
#           'lng': -74.0060844577204}],
#         'distance': 65,
#         'cc': 'US',
#         'state': 'New York',
#         'country': 'United States',
#         'formattedAddress': ['New York', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10d951735',
#          'name': 'Record Shop',
#          'pluralName': 'Record Shops',
#          'shortName': 'Record Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/record_shop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e9c5e940aaf5f690f18825c-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '552572df498e2692b4103b57',
#        'name': 'Neapolitan Express',
#        'location': {'address': '40 Wall St',
#         'lat': 40.70690829999999,
#         'lng': -74.0096853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70690829999999,
#           'lng': -74.0096853}],
#         'distance': 307,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['40 Wall St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '306821',
#         'url': 'https://www.seamless.com/menu/neapolitan-express-40-wall-st-new-york/306821?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=306821',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '139167489'}},
#       'referralId': 'e-0-552572df498e2692b4103b57-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a455daff964a52014a81fe3',
#        'name': "Adrienne's Pizza Bar",
#        'location': {'address': '54 Stone St',
#         'crossStreet': 'Mill Ln',
#         'lat': 40.704348091685645,
#         'lng': -74.01022261314714,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.704348091685645,
#           'lng': -74.01022261314714}],
#         'distance': 304,
#         'postalCode': '10004',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['54 Stone St (Mill Ln)',
#          'New York, NY 10004',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '294545',
#         'url': 'https://www.seamless.com/menu/adriennes-pizza-bar-54-stone-st-new-york/294545?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294545',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '49781819'}},
#       'referralId': 'e-0-4a455daff964a52014a81fe3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ada32224f0e584592628c1f',
#        'name': 'Manhatta',
#        'location': {'address': '28 Liberty St',
#         'lat': 40.70765446542056,
#         'lng': -74.00913779853676,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70765446542056,
#           'lng': -74.00913779853676}],
#         'distance': 335,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['28 Liberty St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ada32224f0e584592628c1f-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a59f31df964a52095b91fe3',
#        'name': "Leo's Bagels",
#        'location': {'address': '3 Hanover Sq',
#         'crossStreet': 'at William St',
#         'lat': 40.704935,
#         'lng': -74.009786,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.704935,
# ...
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aa8259ff964a5209b4f20e3-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b32c707f964a520b91325e3',
#        'name': 'Barclay-Rex Tobacconist',
#        'location': {'address': '90 Water St',
#         'lat': 40.70432180957125,
#         'lng': -74.01114004651347,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70432180957125,
#           'lng': -74.01114004651347}],
#         'distance': 379,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['90 Water St',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d123951735',
#          'name': 'Smoke Shop',
#          'pluralName': 'Smoke Shops',
#          'shortName': 'Smoke Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b32c707f964a520b91325e3-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f9719ebe4b0dd23c4ac1a4e',
#        'name': 'Andaz Lobby Lounge',
#        'location': {'lat': 40.70509649201724,
#         'lng': -74.00802159083338,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70509649201724,
#           'lng': -74.00802159083338}],
#         'distance': 104,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY 10005', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f9719ebe4b0dd23c4ac1a4e-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df76e40d1642d7385a67e45',
#        'name': 'One Medical',
#        'location': {'address': '30 Broad Street, 45th Floor',
#         'crossStreet': 'Wall St',
#         'lat': 40.706204,
#         'lng': -74.011712,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.706204,
#           'lng': -74.011712}],
#         'distance': 428,
#         'postalCode': '10004',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['30 Broad Street, 45th Floor (Wall St)',
#          'New York, NY 10004',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d177941735',
#          'name': "Doctor's Office",
#          'pluralName': "Doctor's Offices",
#          'shortName': "Doctor's Office",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df76e40d1642d7385a67e45-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54e21d97498e7cf9d3f29b3c',
#        'name': 'Fairfield Inn by Marriott New York Manhattan/Financial District',
#        'location': {'address': '161 Front Street',
#         'lat': 40.705911,
#         'lng': -74.004993,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.705911,
#           'lng': -74.004993}],
#         'distance': 170,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['161 Front Street',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '135544945'}},
#       'referralId': 'e-0-54e21d97498e7cf9d3f29b3c-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1464d2127f9521f9d72425',
#        'name': 'Louise Nevelson Plaza',
#        'location': {'address': '10 Liberty St',
#         'crossStreet': 'William st',
#         'lat': 40.70768,
#         'lng': -74.007965,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70768,
#           'lng': -74.007965}],
#         'distance': 290,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['10 Liberty St (William st)',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1464d2127f9521f9d72425-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdfd58e0d69b7132c2b66d3',
#        'name': 'Titanic Memorial Park',
#        'location': {'address': 'Pearl & Fulton St',
#         'crossStreet': 'South Street Seaport',
#         'lat': 40.707504,
#         'lng': -74.003696,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.707504,
#           'lng': -74.003696}],
#         'distance': 364,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Pearl & Fulton St (South Street Seaport)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdfd58e0d69b7132c2b66d3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c02cad10d0e0f47baa9019a',
#        'name': 'Fulton Stall Market',
#        'location': {'address': '91 South St',
#         'crossStreet': 'between Fulton and Beekman St',
#         'lat': 40.707161030974746,
#         'lng': -74.00307476520538,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.707161030974746,
#           'lng': -74.00307476520538}],
#         'distance': 381,
#         'postalCode': '10038',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['91 South St (between Fulton and Beekman St)',
#          'New York, NY 10038',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33708950'}},
#       'referralId': 'e-0-4c02cad10d0e0f47baa9019a-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a3556c0f964a520d49c1fe3',
#        'name': 'Downtown Manhattan Heliport',
#        'location': {'address': 'Pier 6',
#         'crossStreet': 'South St and Broad St',
#         'lat': 40.701621815401744,
#         'lng': -74.00920036408506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.701621815401744,
#           'lng': -74.00920036408506}],
#         'distance': 448,
#         'postalCode': '10004',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Pier 6 (South St and Broad St)',
#          'New York, NY 10004',
#          'United States']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356e',
#          'name': 'Heliport',
#          'pluralName': 'Heliports',
#          'shortName': 'Heliport',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a3556c0f964a520d49c1fe3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '524aeb0111d2ae4d1b1eea62',
#        'name': 'Bluestone Lane',
#        'location': {'address': '30 Broad St',
#         'crossStreet': 'at Exchange Pl',
#         'lat': 40.70626842555141,
#         'lng': -74.0116873383522,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70626842555141,
#           'lng': -74.0116873383522}],
#         'distance': 428,
#         'postalCode': '10004',
#         'cc': 'US',
#         'neighborhood': 'Financial District',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['30 Broad St (at Exchange Pl)',
#          'New York, NY 10004',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-524aeb0111d2ae4d1b1eea62-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '507f06e9e4b0d2368fcbada4',
#        'name': 'Fraunces Tavern',
#        'location': {'address': '54 Pearl St',
#         'crossStreet': 'at Broad St',
#         'lat': 40.70352594119276,
#         'lng': -74.01139528322373,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70352594119276,
#           'lng': -74.01139528322373}],
#         'distance': 431,
#         'postalCode': '10004',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['54 Pearl St (at Broad St)',
#          'New York, NY 10004',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-507f06e9e4b0d2368fcbada4-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59d2188d7247503e69259f80',
#        'name': 'Rise By We',
#        'location': {'address': '85 Broad St',
#         'lat': 40.704025269584655,
#         'lng': -74.01125114411116,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.704025269584655,
#           'lng': -74.01125114411116}],
#         'distance': 398,
#         'postalCode': '10004',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['85 Broad St',
#          'New York, NY 10004',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59d2188d7247503e69259f80-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53380618498ef6a766240fbc',
#        'name': 'Starbucks',
#        'location': {'address': '60 Wall St',
#         'crossStreet': 'at Hanover St',
#         'lat': 40.70608153062632,
#         'lng': -74.00875582404637,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70608153062632,
#           'lng': -74.00875582404637}],
#         'distance': 190,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['60 Wall St (at Hanover St)',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53380618498ef6a766240fbc-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a663a8ef964a5203ec81fe3',
#        'name': 'Federal Hall National Memorial',
#        'location': {'address': '26 Wall St',
#         'crossStreet': 'at Broad St',
#         'lat': 40.70711992999016,
#         'lng': -74.01055172606512,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.70711992999016,
#           'lng': -74.01055172606512}],
#         'distance': 380,
#         'postalCode': '10005',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['26 Wall St (at Broad St)',
#          'New York, NY 10005',
#          'United States']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a663a8ef964a5203ec81fe3-99'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items'] 

nearby_venues = json_normalize(venues)

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]
# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

ManhattenOffice_venues = nearby_venues
ManhattenOffice_venues.head()
# Out:
#                       name        categories        lat        lng
# 0                Crown Shy        Restaurant  40.706187 -74.007490
# 1               sweetgreen       Salad Place  40.705586 -74.008382
# 2     Black Fox Coffee Co.       Coffee Shop  40.706573 -74.008155
# 3  La Colombe Torrefaction       Coffee Shop  40.705899 -74.008421
# 4     East River Esplanade  Pedestrian Plaza  40.704847 -74.004593

# %%
print('Around Manhatten Office, there are over {} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# Around Manhatten Office, there are over 100 venues were returned by Foursquare.

# %% [markdown]
# ### (4) Collect venues around family home locations in Manhatten, New York city
#
# Assume that the family home address is 63 Wall St New York, where is well known 63 Wall St Apartment building.

# %%
address = '63 Wall St, New York, NY'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.70564705 -74.0087563616202

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items'] 
nearby_venues = json_normalize(venues) 

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

ManhattenHome_venues = nearby_venues
ManhattenHome_venues.head()
# Out:
#                       name        categories        lat        lng
# 0                Crown Shy        Restaurant  40.706187 -74.007490
# 1               sweetgreen       Salad Place  40.705586 -74.008382
# 2     Black Fox Coffee Co.       Coffee Shop  40.706573 -74.008155
# 3  La Colombe Torrefaction       Coffee Shop  40.705899 -74.008421
# 4     East River Esplanade  Pedestrian Plaza  40.704847 -74.004593

# %%
print('Around Manhatten Family Home, there are over {} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# Around Manhatten Family Home, there are over 100 venues were returned by Foursquare.

# %% [markdown]
# ## Output four collected New York datasets as local data files

# %%
neighborhoods.to_csv("New_York_neighborhood_data.csv")
manhattan_data.to_csv("Manhattan_neighborhood_data.csv")
ManhattenOffice_venues.to_csv("ManhattanOffice_venues_data.csv")
ManhattenHome_venues.to_csv("ManhattanHome_venues_data.csv")

# %% [markdown]
# ## Collect neighborhood and venue information for Toronto
#
# We will collect the following neighborhood and venue information for Toronto:
#     (1) Neighborhood information for Toronto.
#     (2) Neighborhood information for Toronto financial central location.
#     (3) Venue information for Toronto financial central location.

# %% [markdown]
# ## (1) Collect neighborhood information for Toronto

# %% [markdown]
# The Toronto neighborhood data is scraped from a Wikipedia page. The data was structured into pandas dataframe

# %%
import lxml.html as lh

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(url)
doc = lh.fromstring(page.content)
tr_elements = doc.xpath('//tr')

# %%
col=[]
i=0
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    col.append((name,[]))

# %%
for j in range(1,len(tr_elements)):
    T=tr_elements[j]
    
    if len(T)!=3:
        break
    i=0
    for t in T.iterchildren():
        data=t.text_content() 
        if i>0:
            try:
                data=int(data)
            except:
                pass
        col[i][1].append(data)
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
df.columns = df.columns.str.strip()
df['Neighbourhood'] = df.Neighbourhood.str.replace('\n','')
df.drop(df.loc[df['Borough']=="Not assigned"].index, inplace=True)

# %%
df_group=df.groupby(['Postcode','Borough'],as_index=False)['Neighbourhood'].agg(','.join)

# %%
df_coordinate=pd.read_csv('Geospatial_Coordinates.csv')
df_coordinate.rename(columns={'Postal Code': 'Postcode'}, inplace=True)
df_toronto = df_group.merge(df_coordinate,on='Postcode')

# %%
df_toronto.rename(columns={'Neighbourhood': 'Neighborhood'}, inplace=True)

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df_toronto['Borough'].unique()),
        df_toronto.shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.

# %%
address = 'Toronto City, Canada'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.7189883, -79.44157.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_toronto = df_toronto.drop(['Postcode'], axis=1)

# %%
df_toronto.head()
# Out:
#        Borough                          Neighborhood   Latitude  Longitude
# 0  Scarborough                         Rouge,Malvern  43.806686 -79.194353
# 1  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2  Scarborough       Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3  Scarborough                                Woburn  43.770992 -79.216917
# 4  Scarborough                             Cedarbrae  43.773136 -79.239476

# %%
df_toronto.shape
# Out:
# (103, 4)

# %% [markdown]
# ## (2) Collect neighborhood information for Toronto financial central location

# %% [markdown]
# The Toronto financial center is located in Central Toronto borough. The Central Toronto neighborhood data is a subset from Toronto neighborhood dataset. It is visually shown on a map.

# %%
TorontoCentral_data = df_toronto[df_toronto['Borough'] == 'Central Toronto'].reset_index(drop=True)
TorontoCentral_data.head()
# Out:
#            Borough                Neighborhood   Latitude  Longitude
# 0  Central Toronto               Lawrence Park  43.728020 -79.388790
# 1  Central Toronto            Davisville North  43.712751 -79.390197
# 2  Central Toronto          North Toronto West  43.715383 -79.405678
# 3  Central Toronto                  Davisville  43.704324 -79.388790
# 4  Central Toronto  Moore Park,Summerhill East  43.689574 -79.383160

# %%
address = 'Central Toronto, Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Central Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Central Toronto are 43.653963, -79.387207.

# %%
# create map of Toronto Central using latitude and longitude values
map_TorontoCentral = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(TorontoCentral_data['Latitude'], TorontoCentral_data['Longitude'], TorontoCentral_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_TorontoCentral)  
    
map_TorontoCentral
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## (3) Collect venue information for Toronto financial central location

# %%
print('The geograpical coordinate of Central Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Central Toronto are 43.653963, -79.387207.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items'] 
nearby_venues = json_normalize(venues) 

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

TorontoCentral_venues = nearby_venues
TorontoCentral_venues.head()
# Out:
#                       name        categories        lat        lng
# 0                Crown Shy        Restaurant  40.706187 -74.007490
# 1               sweetgreen       Salad Place  40.705586 -74.008382
# 2     Black Fox Coffee Co.       Coffee Shop  40.706573 -74.008155
# 3  La Colombe Torrefaction       Coffee Shop  40.705899 -74.008421
# 4     East River Esplanade  Pedestrian Plaza  40.704847 -74.004593

# %%
print('Around Central Toronto, there are over {} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# Around Central Toronto, there are over 100 venues were returned by Foursquare.

# %% [markdown]
# ## Output three collected Toronto datasets as local data files

# %%
df_toronto.to_csv("Toronto_neighborhood_data.csv")
TorontoCentral_data.to_csv("TorontoCentral_neighborhood_data.csv")
TorontoCentral_venues.to_csv("TorontoCentral_venues_data.csv")

# %% [markdown]
# ## A description of how the data will be used to solve the problem.

# %% [markdown]
# We will use the above collected datasets in following ways for the second half of this project that will be submitted as Capstone Week 2 project.
#
# For the New York and Manhatten neighborhood and venue datasets, we will analyze to identify the clustering characteristics. Based on such analysis, we will define the selection criterias for the business office and family home locations in Toronto.
#
# For the Toronto neighborhood and venue datasets, we will first analyze the clustering characteristics and to compare with New York and Manhatten data. Based on such analysis and comparison, we will identify potential location options for new business office and family home in Toronto.

# %% [markdown]
# # This concludes Capstone Week 1 project for business description and data collection.
