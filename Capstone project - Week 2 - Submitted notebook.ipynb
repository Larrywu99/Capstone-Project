# %% [markdown]
# # Capstone Project - Relocation from New York City to Toronto
# ### For Applied Data Science Capstone Course by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem Description](#introduction)
# * [Data Collection](#data)
# * [Methodology](#methodology)
# * [Analysis and results](#analysis)
# * [Result Discussion and Recommendations](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem Description <a name="introduction"></a>

# %% [markdown]
# This project is designed to resolve the following assumed business case:
#
# A US business manager who is working for a large financial company and also living in Manhatten, New York city. Recently his company has asked him to relocate to Toronto Canada to lead the efforts to set up a branch business there. He needs to decide where to set up the business office in Toronto. He also needs to select a new residential location for his family, preferrablely in a similar favorable location to his home in Manhatten in New York.
#
# This business manager approached a specialized service company to help him to evaluate the location options in Toronto for both business office and his family home in Toronto. After signing the service contract, this service company starts to work on this project. This project could involve the following aspects:
#
# 1. First to evaluate and to understand the preferred characteristics from this US business manager on his current business office and family home in Manhatten in New York.
# 2. Second to collect and to evaluate information related to Toronto.
# 3. Compare the similarities and differences between New York and Toronto.
# 4. Based on US manager's preferred selection criterias to recommend location options on new business office and residential home in Toronto.
#
# For each of above project aspects, we will conduct relevent data and analyze the data to provide quantitative asscessment. We will work the following data science project steps:
# 1. Collect neighborhood information between New York and Toronto.
# 2. Collect relevant venue information that could be required to compare between New York and Toronto.
# 3. Analyze the collected data to compare the similarities and differences between New York and Toronto.
# 4. Based on US business manager's proposed location selection preference criterias to recommend location options for both busines office and family home in Toronto.

# %% [markdown]
# ## Data Collection <a name="data"></a>

# %% [markdown]
# Based on the above busienss problem descriptinon, we will collect the following data:
# 1. Neighborhood and venue information for New York city, including:
#     (1) Neighborhood information for New York city.
#     (2) Neighborhood information for Manhatten, New York.
#     (3) Venues around existing business office and family home locations in Manhatten, New York city.
#
#
# 2. Neighborhood and venue information for Toronto, including:
#     (1) Neighborhood information for Toronto.
#     (2) Neighborhood information for Toronto financial central location.
#     (3) Venue information for Toronto financial central location.

# %% [markdown]
# ## 1. Collect neighborhood and venue Information for New York city

# %% [markdown]
# ### (1) Collect neighborhood Information for New York city
#
# To get New York neighborhood information, we first download existing dataset newyork_data online. We convert the online dataset into pandas dataframe. The neighborhood information is then visualized on New York map.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %% [markdown]
# The next is to transform the data into a pandas dataframe.

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
# neighborhoods.head()

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %% [markdown]
# Use geopy library to get the latitude and longitude values of New York City

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_newyork = neighborhoods
df_newyork.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %% [markdown]
# ### (2) Collect neighborhood Information for Manhatten, New York
#
# The Manhatten neighborhood data is a subset from New York neighborhood dataset. The data is visualized on a map.

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head(40)
# Out:
#       Borough         Neighborhood   Latitude  Longitude
# 0   Manhattan          Marble Hill  40.876551 -73.910660
# 1   Manhattan            Chinatown  40.715618 -73.994279
# 2   Manhattan   Washington Heights  40.851903 -73.936900
# 3   Manhattan               Inwood  40.867684 -73.921210
# 4   Manhattan     Hamilton Heights  40.823604 -73.949688
# 5   Manhattan       Manhattanville  40.816934 -73.957385
# 6   Manhattan       Central Harlem  40.815976 -73.943211
# 7   Manhattan          East Harlem  40.792249 -73.944182
# 8   Manhattan      Upper East Side  40.775639 -73.960508
# 9   Manhattan            Yorkville  40.775930 -73.947118
# 10  Manhattan           Lenox Hill  40.768113 -73.958860
# 11  Manhattan     Roosevelt Island  40.762160 -73.949168
# 12  Manhattan      Upper West Side  40.787658 -73.977059
# 13  Manhattan       Lincoln Square  40.773529 -73.985338
# 14  Manhattan              Clinton  40.759101 -73.996119
# 15  Manhattan              Midtown  40.754691 -73.981669
# 16  Manhattan          Murray Hill  40.748303 -73.978332
# 17  Manhattan              Chelsea  40.744035 -74.003116
# 18  Manhattan    Greenwich Village  40.726933 -73.999914
# 19  Manhattan         East Village  40.727847 -73.982226
# 20  Manhattan      Lower East Side  40.717807 -73.980890
# 21  Manhattan              Tribeca  40.721522 -74.010683
# 22  Manhattan         Little Italy  40.719324 -73.997305
# 23  Manhattan                 Soho  40.722184 -74.000657
# 24  Manhattan         West Village  40.734434 -74.006180
# 25  Manhattan     Manhattan Valley  40.797307 -73.964286
# 26  Manhattan  Morningside Heights  40.808000 -73.963896
# 27  Manhattan             Gramercy  40.737210 -73.981376
# 28  Manhattan    Battery Park City  40.711932 -74.016869
# 29  Manhattan   Financial District  40.707107 -74.010665
# 30  Manhattan        Carnegie Hill  40.782683 -73.953256
# 31  Manhattan                 Noho  40.723259 -73.988434
# 32  Manhattan         Civic Center  40.715229 -74.005415
# 33  Manhattan        Midtown South  40.748510 -73.988713
# 34  Manhattan         Sutton Place  40.760280 -73.963556
# 35  Manhattan           Turtle Bay  40.752042 -73.967708
# 36  Manhattan           Tudor City  40.746917 -73.971219
# 37  Manhattan      Stuyvesant Town  40.731000 -73.974052
# 38  Manhattan             Flatiron  40.739673 -73.990947
# 39  Manhattan         Hudson Yards  40.756658 -74.000111

# %%
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 40.7900869, -73.9598295.

# %%
# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### (3) Collect venues around existing business office and family home locations in Manhattan, New York city
#
# We assume that the business office address is 100 Wall St New York, near New York Stock Exchange location.

# %% [markdown]
# ### Collect venues around existing business office in Manhattan, New York city

# %% [markdown]
# #### We are using Foursqure API to collect venue information

# %%
CLIENT_ID = '0D33T0AVFXWBBXCZDHJ2IA32T5GG5IK1J5GYXBAIP14Z4KRF' # your Foursquare ID
CLIENT_SECRET = '0L2NKXGCDXVV3HLBJDOJDSNIOPCOODUIZOQQECZ4DC5F2ZIQ' # your Foursquare Secret
VERSION = '20180604'

# %%
address = '100 Wall St, New York, NY'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7052203 -74.006799602293

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
#url

# %%
results = requests.get(url).json()
#results

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items'] 

nearby_venues = json_normalize(venues)

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]
# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

Manhattan_venues = nearby_venues
Manhattan_venues.head()
# Out:
#                       name        categories        lat        lng
# 0                Crown Shy        Restaurant  40.706187 -74.007490
# 1               sweetgreen       Salad Place  40.705586 -74.008382
# 2     Black Fox Coffee Co.       Coffee Shop  40.706573 -74.008155
# 3  La Colombe Torrefaction       Coffee Shop  40.705899 -74.008421
# 4     East River Esplanade  Pedestrian Plaza  40.704847 -74.004593

# %%
Manhattan_venues.shape
# Out:
# (100, 4)

# %%
print('Around Manhattan Office, there are over {} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# Around Manhattan Office, there are over 100 venues were returned by Foursquare.

# %% [markdown]
# ### Explore Neighborhoods in Manhattan

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards

# %%
print(manhattan_venues.shape)
manhattan_venues.head()
# Out:
# (3329, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude          Venue  \
# 0  Marble Hill              40.876551               -73.91066       Arturo's
# 1  Marble Hill              40.876551               -73.91066    Bikram Yoga
# 2  Marble Hill              40.876551               -73.91066  Tibbett Diner
# 3  Marble Hill              40.876551               -73.91066      Starbucks
# 4  Marble Hill              40.876551               -73.91066        Dunkin'
#
#    Venue Latitude  Venue Longitude Venue Category
# 0       40.874412       -73.910271    Pizza Place
# 1       40.876844       -73.906204    Yoga Studio
# 2       40.880404       -73.908937          Diner
# 3       40.877531       -73.905582    Coffee Shop
# 4       40.877136       -73.906666     Donut Shop

# %% [markdown]
# ## Output collected New York datasets as local data files

# %%
neighborhoods.to_csv("New_York_neighborhood_data.csv")
manhattan_data.to_csv("Manhattan_neighborhood_data.csv")
Manhattan_venues.to_csv("ManhattanOffice_venues_data.csv")

# %% [markdown]
# ## Collect neighborhood and venue information for Toronto
#
# We will collect the following neighborhood and venue information for Toronto:
#     (1) Neighborhood information for Toronto.
#     (2) Neighborhood information for Toronto financial central location.
#     (3) Venue information for Toronto financial central location.

# %% [markdown]
# ## (1) Collect neighborhood information for Toronto

# %% [markdown]
# The Toronto neighborhood data is scraped from a Wikipedia page. The data was structured into pandas dataframe

# %%
import lxml.html as lh

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(url)
doc = lh.fromstring(page.content)
tr_elements = doc.xpath('//tr')

# %%
col=[]
i=0
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    col.append((name,[]))

# %%
for j in range(1,len(tr_elements)):
    T=tr_elements[j]
    
    if len(T)!=3:
        break
    i=0
    for t in T.iterchildren():
        data=t.text_content() 
        if i>0:
            try:
                data=int(data)
            except:
                pass
        col[i][1].append(data)
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
df.columns = df.columns.str.strip()
df['Neighbourhood'] = df.Neighbourhood.str.replace('\n','')
df.drop(df.loc[df['Borough']=="Not assigned"].index, inplace=True)

# %%
df_group=df.groupby(['Postcode','Borough'],as_index=False)['Neighbourhood'].agg(','.join)

# %%
df_coordinate=pd.read_csv('Geospatial_Coordinates.csv')
df_coordinate.rename(columns={'Postal Code': 'Postcode'}, inplace=True)
df_toronto = df_group.merge(df_coordinate,on='Postcode')

# %%
df_toronto.rename(columns={'Neighbourhood': 'Neighborhood'}, inplace=True)

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df_toronto['Borough'].unique()),
        df_toronto.shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.

# %%
address = 'Toronto City, Canada'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.7189883, -79.44157.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_toronto = df_toronto.drop(['Postcode'], axis=1)

# %%
df_toronto.head()
# Out:
#        Borough                          Neighborhood   Latitude  Longitude
# 0  Scarborough                         Rouge,Malvern  43.806686 -79.194353
# 1  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2  Scarborough       Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3  Scarborough                                Woburn  43.770992 -79.216917
# 4  Scarborough                             Cedarbrae  43.773136 -79.239476

# %%
df_toronto.shape
# Out:
# (103, 4)

# %% [markdown]
# ## (2) Collect neighborhood information for Central Toronto, the financial central location

# %% [markdown]
# The Toronto financial center is located in Central Toronto borough. The Central Toronto neighborhood data is a subset from Toronto neighborhood dataset. It is visually shown on a map.

# %%
TorontoCentral_data = df_toronto[df_toronto['Borough'] == 'Central Toronto'].reset_index(drop=True)
TorontoCentral_data.head()
# Out:
#            Borough                Neighborhood   Latitude  Longitude
# 0  Central Toronto               Lawrence Park  43.728020 -79.388790
# 1  Central Toronto            Davisville North  43.712751 -79.390197
# 2  Central Toronto          North Toronto West  43.715383 -79.405678
# 3  Central Toronto                  Davisville  43.704324 -79.388790
# 4  Central Toronto  Moore Park,Summerhill East  43.689574 -79.383160

# %%
address = 'Central Toronto, Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Central Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Central Toronto are 43.653963, -79.387207.

# %%
# create map of Toronto Central using latitude and longitude values
map_TorontoCentral = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(TorontoCentral_data['Latitude'], TorontoCentral_data['Longitude'], TorontoCentral_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_TorontoCentral)  
    
map_TorontoCentral
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## (3) Collect venue information for Central Toronto, the financial center

# %%
print('The geograpical coordinate of Central Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Central Toronto are 43.653963, -79.387207.

# %% [markdown]
# #### Let's create a function to repeat the same process to all the neighborhoods in Central Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Now write the code to run the above function on each neighborhood and create a new dataframe called *manhattan_venues*.

# %%
TorontoCentral_venues = getNearbyVenues(names=TorontoCentral_data['Neighborhood'],
                                   latitudes=TorontoCentral_data['Latitude'],
                                   longitudes=TorontoCentral_data['Longitude']
                                  )
# Out:
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park,Summerhill East
# Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West
# Roselawn
# Forest Hill North,Forest Hill West
# The Annex,North Midtown,Yorkville

# %%
print(TorontoCentral_venues.shape)
TorontoCentral_venues.head()
# Out:
# (112, 7)
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0     Lawrence Park              43.728020              -79.388790
# 1     Lawrence Park              43.728020              -79.388790
# 2     Lawrence Park              43.728020              -79.388790
# 3  Davisville North              43.712751              -79.390197
# 4  Davisville North              43.712751              -79.390197
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 0            Lawrence Park Ravine       43.726963       -79.394382
# 1              Zodiac Swim School       43.728532       -79.382860
# 2  TTC Bus #162 - Lawrence-Donway       43.728026       -79.382805
# 3                   Sherwood Park       43.716551       -79.387776
# 4         Summerhill Market North       43.715499       -79.392881
#
#       Venue Category
# 0               Park
# 1        Swim School
# 2           Bus Line
# 3               Park
# 4  Food & Drink Shop

# %%
TorontoCentral_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Davisville                                                             35
# Davisville North                                                        7
# Deer Park,Forest Hill SE,Rathnelly,South Hill,S...                     16
# Forest Hill North,Forest Hill West                                      4
# Lawrence Park                                                           3
# Moore Park,Summerhill East                                              4
# North Toronto West                                                     18
# Roselawn                                                                1
# The Annex,North Midtown,Yorkville                                      24
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Davisville                                                              35
# Davisville North                                                         7
# Deer Park,Forest Hill SE,Rathnelly,South Hill,S...                      16
# Forest Hill North,Forest Hill West                                       4
# Lawrence Park                                                            3
# Moore Park,Summerhill East                                               4
# North Toronto West                                                      18
# Roselawn                                                                 1
# The Annex,North Midtown,Yorkville                                       24
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Davisville                                             35              35
# Davisville North                                        7               7
# Deer Park,Forest Hill SE,Rathnelly,South Hill,S...     16              16
# Forest Hill North,Forest Hill West                      4               4
# Lawrence Park                                           3               3
# Moore Park,Summerhill East                              4               4
# North Toronto West                                     18              18
# Roselawn                                                1               1
# The Annex,North Midtown,Yorkville                      24              24
#
#                                                     Venue Longitude  \
# Neighborhood
# Davisville                                                       35
# Davisville North                                                  7
# Deer Park,Forest Hill SE,Rathnelly,South Hill,S...               16
# Forest Hill North,Forest Hill West                                4
# Lawrence Park                                                     3
# Moore Park,Summerhill East                                        4
# North Toronto West                                               18
# Roselawn                                                          1
# The Annex,North Midtown,Yorkville                                24
#
#                                                     Venue Category
# Neighborhood
# Davisville                                                      35
# Davisville North                                                 7
# Deer Park,Forest Hill SE,Rathnelly,South Hill,S...              16
# Forest Hill North,Forest Hill West                               4
# Lawrence Park                                                    3
# Moore Park,Summerhill East                                       4
# North Toronto West                                              18
# Roselawn                                                         1
# The Annex,North Midtown,Yorkville                               24

# %%
print('There are {} uniques categories.'.format(len(TorontoCentral_venues['Venue Category'].unique())))
# Out:
# There are 59 uniques categories.

# %% [markdown]
# ## Output collected Toronto datasets as local data files

# %%
df_toronto.to_csv("Toronto_neighborhood_data.csv")
TorontoCentral_data.to_csv("TorontoCentral_neighborhood_data.csv")
TorontoCentral_data.to_json("TorontoCentral_neighborhood_data.json")
TorontoCentral_venues.to_csv("TorontoCentral_venues_data.csv")
TorontoCentral_venues.to_json("TorontoCentral_venues_data.json")

# %% [markdown]
# ## Methodology

# %% [markdown]
# ### In this project, we will use the following methods to analyze the data:
#
# 1. First, we will compare the total number of venues between Manhattan and Centrol Toronto. Such total venue number comparison could show the similarities and differences in terms of overall venue availability and distribution.
#
# 2. Second, for each neighborhood, we will rank top venues based on venue grouping. Such ranking information could show what venues are more available for a specific neighborhood. This local venue availability and concentration information will be valuable to match preferred venues with neighborhood options.
#
# 3. Third, we will apply k-means clustering to analyze the distribution of venue categories within different neighborhoods for both Manhattan and Central Toronto. This statistic significance based results could give good venue clustering distribution information for location selection.
#
# ### To further refine the location selection criteria, we will specify the following US business manager's selection preferences for potential location selection options:
#
# 1. For new business office in Toronto, prefer location options at central financial district that exhibits similar venue clustering and vailability as those in Manhattan finncial district.
#
# 2. For new family home in Toronto, prefer location options that have good availability in recreation and social venues, such as park, musium and restaurants.
#
# After proposing potential location options, we will also identify areas for further study to refine the location search by incorporating feedbacks and improvement suggestions from US business manager and his company decison  makers after presenting this project report.

# %% [markdown]
# ## Analysis and Results <a name="analysis"></a>

# %% [markdown]
# ##  Analyze Manhatten Neighborhood and Results

# %% [markdown]
# #### Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
# one hot encoding
manhattan_onehot = pd.get_dummies(manhattan_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
manhattan_onehot['Neighborhood'] = manhattan_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [manhattan_onehot.columns[-1]] + list(manhattan_onehot.columns[:-1])
manhattan_onehot = manhattan_onehot[fixed_columns]

# manhattan_onehot.head()

# %%
manhattan_grouped = manhattan_onehot.groupby('Neighborhood').mean().reset_index()
#manhattan_grouped

# %%
manhattan_grouped.shape
# Out:
# (40, 340)

# %% [markdown]
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = manhattan_grouped['Neighborhood']

for ind in np.arange(manhattan_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(manhattan_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(20)
# Out:
#           Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0    Battery Park City                  Park           Coffee Shop
# 1        Carnegie Hill           Coffee Shop           Pizza Place
# 2       Central Harlem    African Restaurant     French Restaurant
# 3              Chelsea           Coffee Shop    Italian Restaurant
# 4            Chinatown    Chinese Restaurant          Cocktail Bar
# 5         Civic Center  Gym / Fitness Center    Italian Restaurant
# 6              Clinton               Theater  Gym / Fitness Center
# 7          East Harlem    Mexican Restaurant                Bakery
# 8         East Village                   Bar              Wine Bar
# 9   Financial District           Coffee Shop                 Hotel
# 10            Flatiron                   Gym           Yoga Studio
# 11            Gramercy                   Bar    Italian Restaurant
# 12   Greenwich Village    Italian Restaurant        Clothing Store
# 13    Hamilton Heights           Pizza Place           Coffee Shop
# 14        Hudson Yards   American Restaurant    Italian Restaurant
# 15              Inwood    Mexican Restaurant                Lounge
# 16          Lenox Hill           Coffee Shop    Italian Restaurant
# 17      Lincoln Square  Gym / Fitness Center               Theater
# 18        Little Italy                Bakery                  Café
# 19     Lower East Side           Coffee Shop      Ramen Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0                  Hotel                   Gym              Memorial Site
# 1                    Bar           Yoga Studio                        Spa
# 2     Chinese Restaurant            Public Art             Cosmetics Shop
# 3         Ice Cream Shop                Bakery                  Nightclub
# 4    American Restaurant    Salon / Barbershop      Vietnamese Restaurant
# 5            Coffee Shop     French Restaurant                      Hotel
# 6                  Hotel   American Restaurant         Italian Restaurant
# 7          Deli / Bodega           Pizza Place  Latin American Restaurant
# 8     Chinese Restaurant    Mexican Restaurant             Ice Cream Shop
# 9              Wine Shop            Steakhouse                        Gym
# 10   American Restaurant   Japanese Restaurant             Clothing Store
# 11          Cocktail Bar   American Restaurant                Pizza Place
# 12      Sushi Restaurant                  Café         Seafood Restaurant
# 13    Mexican Restaurant                  Café                Yoga Studio
# 14  Gym / Fitness Center                  Café         Spanish Restaurant
# 15                  Café           Pizza Place              Deli / Bodega
# 16           Pizza Place      Sushi Restaurant       Gym / Fitness Center
# 17                  Café          Concert Hall                      Plaza
# 18       Bubble Tea Shop        Clothing Store             Sandwich Place
# 19           Pizza Place                  Café        Japanese Restaurant
#
#    6th Most Common Venue     7th Most Common Venue  \
# 0          Boat or Ferry        Italian Restaurant
# 1                 Bakery                 Bookstore
# 2     Seafood Restaurant                       Bar
# 3    American Restaurant        Seafood Restaurant
# 4        Bubble Tea Shop                       Spa
# 5         Sandwich Place       Sporting Goods Shop
# 6              Wine Shop            Sandwich Place
# 7        Thai Restaurant                       Spa
# 8            Pizza Place          Ramen Restaurant
# 9           Cocktail Bar               Pizza Place
# 10  Gym / Fitness Center              Cycle Studio
# 11            Bagel Shop        Mexican Restaurant
# 12     Indian Restaurant            Cosmetics Shop
# 13     Indian Restaurant          Sushi Restaurant
# 14            Restaurant                     Hotel
# 15              Wine Bar       American Restaurant
# 16   Sporting Goods Shop              Burger Joint
# 17    Italian Restaurant         French Restaurant
# 18    Salon / Barbershop  Mediterranean Restaurant
# 19           Art Gallery                    Bakery
#
#             8th Most Common Venue    9th Most Common Venue  \
# 0                       Wine Shop             Cupcake Shop
# 1                            Café           Cosmetics Shop
# 2             American Restaurant                Bookstore
# 3                     Art Gallery                  Theater
# 4             Dumpling Restaurant                   Bakery
# 5             American Restaurant                   Bakery
# 6                     Coffee Shop                      Spa
# 7                        Beer Bar                      Gym
# 8   Vegetarian / Vegan Restaurant              Coffee Shop
# 9            Gym / Fitness Center       Italian Restaurant
# 10             Salon / Barbershop  New American Restaurant
# 11                          Hotel            Grocery Store
# 12             Chinese Restaurant        French Restaurant
# 13                 Sandwich Place            Deli / Bodega
# 14                 Sandwich Place              Coffee Shop
# 15                         Bakery               Restaurant
# 16                 Cosmetics Shop                      Gym
# 17                    Opera House                     Park
# 18                 Ice Cream Shop              Yoga Studio
# 19             Chinese Restaurant             Cocktail Bar
#
#     10th Most Common Venue
# 0                BBQ Joint
# 1            Grocery Store
# 2                 Beer Bar
# 3                    Hotel
# 4     Cantonese Restaurant
# 5             Cocktail Bar
# 6                 Wine Bar
# 7            Grocery Store
# 8             Cocktail Bar
# 9      American Restaurant
# 10            Dessert Shop
# 11  Thrift / Vintage Store
# 12            Burger Joint
# 13                  School
# 14          Ice Cream Shop
# 15      Frozen Yogurt Shop
# 16            Cocktail Bar
# 17   Performing Arts Venue
# 18     Japanese Restaurant
# 19                    Park

# %% [markdown]
# ###  Run *k*-means to cluster the Manhattan neighborhood into 5 clusters

# %%
kclusters = 5

manhattan_grouped_clustering = manhattan_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(manhattan_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 1, 1, 1, 1, 1, 0, 1, 1], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

manhattan_merged = manhattan_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
manhattan_merged = manhattan_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

#manhattan_merged = manhattan_merged.drop(['Unnamed:0'], axis=1)
manhattan_merged.head(30) # check the last columns!
# Out:
#       Borough         Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0   Manhattan          Marble Hill  40.876551 -73.910660               4
# 1   Manhattan            Chinatown  40.715618 -73.994279               1
# 2   Manhattan   Washington Heights  40.851903 -73.936900               2
# 3   Manhattan               Inwood  40.867684 -73.921210               2
# 4   Manhattan     Hamilton Heights  40.823604 -73.949688               0
# 5   Manhattan       Manhattanville  40.816934 -73.957385               2
# 6   Manhattan       Central Harlem  40.815976 -73.943211               1
# 7   Manhattan          East Harlem  40.792249 -73.944182               0
# 8   Manhattan      Upper East Side  40.775639 -73.960508               1
# 9   Manhattan            Yorkville  40.775930 -73.947118               1
# 10  Manhattan           Lenox Hill  40.768113 -73.958860               1
# 11  Manhattan     Roosevelt Island  40.762160 -73.949168               1
# 12  Manhattan      Upper West Side  40.787658 -73.977059               1
# 13  Manhattan       Lincoln Square  40.773529 -73.985338               1
# 14  Manhattan              Clinton  40.759101 -73.996119               1
# 15  Manhattan              Midtown  40.754691 -73.981669               1
# 16  Manhattan          Murray Hill  40.748303 -73.978332               1
# 17  Manhattan              Chelsea  40.744035 -74.003116               1
# 18  Manhattan    Greenwich Village  40.726933 -73.999914               1
# 19  Manhattan         East Village  40.727847 -73.982226               1
# 20  Manhattan      Lower East Side  40.717807 -73.980890               2
# 21  Manhattan              Tribeca  40.721522 -74.010683               1
# 22  Manhattan         Little Italy  40.719324 -73.997305               1
# 23  Manhattan                 Soho  40.722184 -74.000657               1
# 24  Manhattan         West Village  40.734434 -74.006180               1
# 25  Manhattan     Manhattan Valley  40.797307 -73.964286               0
# 26  Manhattan  Morningside Heights  40.808000 -73.963896               2
# 27  Manhattan             Gramercy  40.737210 -73.981376               1
# 28  Manhattan    Battery Park City  40.711932 -74.016869               1
# 29  Manhattan   Financial District  40.707107 -74.010665               1
#
#    1st Most Common Venue    2nd Most Common Venue 3rd Most Common Venue  \
# 0         Sandwich Place           Discount Store           Coffee Shop
# 1     Chinese Restaurant             Cocktail Bar   American Restaurant
# 2                   Café                   Bakery     Mobile Phone Shop
# 3     Mexican Restaurant                   Lounge                  Café
# 4            Pizza Place              Coffee Shop    Mexican Restaurant
# 5     Italian Restaurant       Mexican Restaurant    Seafood Restaurant
# 6     African Restaurant        French Restaurant    Chinese Restaurant
# 7     Mexican Restaurant                   Bakery         Deli / Bodega
# 8     Italian Restaurant                  Exhibit           Art Gallery
# 9     Italian Restaurant                      Gym           Coffee Shop
# 10           Coffee Shop       Italian Restaurant           Pizza Place
# 11           Coffee Shop           Sandwich Place                  Park
# 12    Italian Restaurant                 Wine Bar                   Bar
# 13  Gym / Fitness Center                  Theater                  Café
# 14               Theater     Gym / Fitness Center                 Hotel
# 15                 Hotel              Coffee Shop          Cocktail Bar
# 16           Coffee Shop                    Hotel        Sandwich Place
# 17           Coffee Shop       Italian Restaurant        Ice Cream Shop
# 18    Italian Restaurant           Clothing Store      Sushi Restaurant
# 19                   Bar                 Wine Bar    Chinese Restaurant
# 20           Coffee Shop         Ramen Restaurant           Pizza Place
# 21    Italian Restaurant                      Spa                  Park
# 22                Bakery                     Café       Bubble Tea Shop
# 23        Clothing Store                 Boutique           Art Gallery
# 24    Italian Restaurant  New American Restaurant   American Restaurant
# 25     Indian Restaurant              Pizza Place           Coffee Shop
# 26           Coffee Shop      American Restaurant                  Park
# 27                   Bar       Italian Restaurant          Cocktail Bar
# 28                  Park              Coffee Shop                 Hotel
# 29           Coffee Shop                    Hotel             Wine Shop
#
#             4th Most Common Venue      5th Most Common Venue  \
# 0                     Yoga Studio                 Steakhouse
# 1              Salon / Barbershop      Vietnamese Restaurant
# 2                   Grocery Store         Spanish Restaurant
# 3                     Pizza Place              Deli / Bodega
# 4                            Café                Yoga Studio
# 5                            Park                Coffee Shop
# 6                      Public Art             Cosmetics Shop
# 7                     Pizza Place  Latin American Restaurant
# 8                          Bakery       Gym / Fitness Center
# 9                             Bar                Pizza Place
# 10               Sushi Restaurant       Gym / Fitness Center
# 11                  Indie Theater                Dry Cleaner
# 12  Vegetarian / Vegan Restaurant   Mediterranean Restaurant
# 13                   Concert Hall                      Plaza
# 14            American Restaurant         Italian Restaurant
# 15                        Theater             Clothing Store
# 16            Japanese Restaurant         Italian Restaurant
# 17                         Bakery                  Nightclub
# 18                           Café         Seafood Restaurant
# 19             Mexican Restaurant             Ice Cream Shop
# 20                           Café        Japanese Restaurant
# 21                           Café        American Restaurant
# 22                 Clothing Store             Sandwich Place
# 23                     Shoe Store              Women's Store
# 24                 Cosmetics Shop                   Wine Bar
# 25                    Yoga Studio                 Playground
# 26                      Bookstore               Burger Joint
# 27            American Restaurant                Pizza Place
# 28                            Gym              Memorial Site
# 29                     Steakhouse                        Gym
#
#    6th Most Common Venue     7th Most Common Venue  \
# 0        Supplement Shop             Shopping Mall
# 1        Bubble Tea Shop                       Spa
# 2            Coffee Shop          Tapas Restaurant
# 3               Wine Bar       American Restaurant
# 4      Indian Restaurant          Sushi Restaurant
# 5          Deli / Bodega               Supermarket
# 6     Seafood Restaurant                       Bar
# 7        Thai Restaurant                       Spa
# 8              Juice Bar               Coffee Shop
# 9       Sushi Restaurant                 Wine Shop
# 10   Sporting Goods Shop              Burger Joint
# 11              Bus Stop           Bubble Tea Shop
# 12                Bakery         Indian Restaurant
# 13    Italian Restaurant         French Restaurant
# 14             Wine Shop            Sandwich Place
# 15   American Restaurant                       Spa
# 16  Gym / Fitness Center                       Gym
# 17   American Restaurant        Seafood Restaurant
# 18     Indian Restaurant            Cosmetics Shop
# 19           Pizza Place          Ramen Restaurant
# 20           Art Gallery                    Bakery
# 21              Boutique                 Wine Shop
# 22    Salon / Barbershop  Mediterranean Restaurant
# 23    Italian Restaurant       Sporting Goods Shop
# 24             Jazz Club                      Park
# 25                   Bar                      Café
# 26            Food Truck             Deli / Bodega
# 27            Bagel Shop        Mexican Restaurant
# 28         Boat or Ferry        Italian Restaurant
# 29          Cocktail Bar               Pizza Place
#
#             8th Most Common Venue      9th Most Common Venue  \
# 0              Seafood Restaurant             Tennis Stadium
# 1             Dumpling Restaurant                     Bakery
# 2         New American Restaurant  Latin American Restaurant
# 3                          Bakery                 Restaurant
# 4                  Sandwich Place              Deli / Bodega
# 5                    Burger Joint         Spanish Restaurant
# 6             American Restaurant                  Bookstore
# 7                        Beer Bar                        Gym
# 8               French Restaurant                      Hotel
# 9             Japanese Restaurant              Deli / Bodega
# 10                 Cosmetics Shop                        Gym
# 11                  Deli / Bodega                Supermarket
# 12                 Cosmetics Shop                Coffee Shop
# 13                    Opera House                       Park
# 14                    Coffee Shop                        Spa
# 15                         Bakery                  Bookstore
# 16              French Restaurant                        Spa
# 17                    Art Gallery                    Theater
# 18             Chinese Restaurant          French Restaurant
# 19  Vegetarian / Vegan Restaurant                Coffee Shop
# 20             Chinese Restaurant               Cocktail Bar
# 21                       Wine Bar                        Gym
# 22                 Ice Cream Shop                Yoga Studio
# 23                    Men's Store   Mediterranean Restaurant
# 24                   Cocktail Bar                  Speakeasy
# 25             Mexican Restaurant         Chinese Restaurant
# 26                   Tennis Court          Indian Restaurant
# 27                          Hotel              Grocery Store
# 28                      Wine Shop               Cupcake Shop
# 29           Gym / Fitness Center         Italian Restaurant
#
#     10th Most Common Venue
# 0                      Gym
# 1     Cantonese Restaurant
# 2                     Park
# 3       Frozen Yogurt Shop
# 4                   School
# 5              Bus Station
# 6                 Beer Bar
# 7            Grocery Store
# 8                      Spa
# 9       Mexican Restaurant
# 10            Cocktail Bar
# 11          Farmers Market
# 12                     Pub
# 13   Performing Arts Venue
# 14                Wine Bar
# 15     Sporting Goods Shop
# 16                     Bar
# 17                   Hotel
# 18            Burger Joint
# 19            Cocktail Bar
# 20                    Park
# 21        Greek Restaurant
# 22     Japanese Restaurant
# 23                   Hotel
# 24             Coffee Shop
# 25         Thai Restaurant
# 26       Outdoor Sculpture
# 27  Thrift / Vintage Store
# 28               BBQ Joint
# 29     American Restaurant

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
address = 'Manhattan, New York'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 40.7900869, -73.9598295.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Manhattan venue clusters
# Examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %% [markdown]
# #### Cluster 1

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 0, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 4   Hamilton Heights           Pizza Place           Coffee Shop
# 7        East Harlem    Mexican Restaurant                Bakery
# 25  Manhattan Valley     Indian Restaurant           Pizza Place
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 4     Mexican Restaurant                  Café                Yoga Studio
# 7          Deli / Bodega           Pizza Place  Latin American Restaurant
# 25           Coffee Shop           Yoga Studio                 Playground
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 4      Indian Restaurant      Sushi Restaurant        Sandwich Place
# 7        Thai Restaurant                   Spa              Beer Bar
# 25                   Bar                  Café    Mexican Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 4          Deli / Bodega                 School
# 7                    Gym          Grocery Store
# 25    Chinese Restaurant        Thai Restaurant

# %% [markdown]
# #### Cluster 2

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 1, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#           Neighborhood 1st Most Common Venue    2nd Most Common Venue  \
# 1            Chinatown    Chinese Restaurant             Cocktail Bar
# 6       Central Harlem    African Restaurant        French Restaurant
# 8      Upper East Side    Italian Restaurant                  Exhibit
# 9            Yorkville    Italian Restaurant                      Gym
# 10          Lenox Hill           Coffee Shop       Italian Restaurant
# 11    Roosevelt Island           Coffee Shop           Sandwich Place
# 12     Upper West Side    Italian Restaurant                 Wine Bar
# 13      Lincoln Square  Gym / Fitness Center                  Theater
# 14             Clinton               Theater     Gym / Fitness Center
# 15             Midtown                 Hotel              Coffee Shop
# 16         Murray Hill           Coffee Shop                    Hotel
# 17             Chelsea           Coffee Shop       Italian Restaurant
# 18   Greenwich Village    Italian Restaurant           Clothing Store
# 19        East Village                   Bar                 Wine Bar
# 21             Tribeca    Italian Restaurant                      Spa
# 22        Little Italy                Bakery                     Café
# 23                Soho        Clothing Store                 Boutique
# 24        West Village    Italian Restaurant  New American Restaurant
# 27            Gramercy                   Bar       Italian Restaurant
# 28   Battery Park City                  Park              Coffee Shop
# 29  Financial District           Coffee Shop                    Hotel
# 30       Carnegie Hill           Coffee Shop              Pizza Place
# 31                Noho    Italian Restaurant        French Restaurant
# 32        Civic Center  Gym / Fitness Center       Italian Restaurant
# 33       Midtown South     Korean Restaurant                    Hotel
# 34        Sutton Place  Gym / Fitness Center       Italian Restaurant
# 35          Turtle Bay    Italian Restaurant               Steakhouse
# 38            Flatiron                   Gym              Yoga Studio
# 39        Hudson Yards   American Restaurant       Italian Restaurant
#
#      3rd Most Common Venue          4th Most Common Venue  \
# 1      American Restaurant             Salon / Barbershop
# 6       Chinese Restaurant                     Public Art
# 8              Art Gallery                         Bakery
# 9              Coffee Shop                            Bar
# 10             Pizza Place               Sushi Restaurant
# 11                    Park                  Indie Theater
# 12                     Bar  Vegetarian / Vegan Restaurant
# 13                    Café                   Concert Hall
# 14                   Hotel            American Restaurant
# 15            Cocktail Bar                        Theater
# 16          Sandwich Place            Japanese Restaurant
# 17          Ice Cream Shop                         Bakery
# 18        Sushi Restaurant                           Café
# 19      Chinese Restaurant             Mexican Restaurant
# 21                    Park                           Café
# 22         Bubble Tea Shop                 Clothing Store
# 23             Art Gallery                     Shoe Store
# 24     American Restaurant                 Cosmetics Shop
# 27            Cocktail Bar            American Restaurant
# 28                   Hotel                            Gym
# 29               Wine Shop                     Steakhouse
# 30                     Bar                    Yoga Studio
# 31        Sushi Restaurant                   Cocktail Bar
# 32             Coffee Shop              French Restaurant
# 33            Dessert Shop            American Restaurant
# 34  Furniture / Home Store              Indian Restaurant
# 35        Sushi Restaurant                    Coffee Shop
# 38     American Restaurant            Japanese Restaurant
# 39    Gym / Fitness Center                           Café
#
#        5th Most Common Venue 6th Most Common Venue     7th Most Common Venue  \
# 1      Vietnamese Restaurant       Bubble Tea Shop                       Spa
# 6             Cosmetics Shop    Seafood Restaurant                       Bar
# 8       Gym / Fitness Center             Juice Bar               Coffee Shop
# 9                Pizza Place      Sushi Restaurant                 Wine Shop
# 10      Gym / Fitness Center   Sporting Goods Shop              Burger Joint
# 11               Dry Cleaner              Bus Stop           Bubble Tea Shop
# 12  Mediterranean Restaurant                Bakery         Indian Restaurant
# 13                     Plaza    Italian Restaurant         French Restaurant
# 14        Italian Restaurant             Wine Shop            Sandwich Place
# 15            Clothing Store   American Restaurant                       Spa
# 16        Italian Restaurant  Gym / Fitness Center                       Gym
# 17                 Nightclub   American Restaurant        Seafood Restaurant
# 18        Seafood Restaurant     Indian Restaurant            Cosmetics Shop
# 19            Ice Cream Shop           Pizza Place          Ramen Restaurant
# 21       American Restaurant              Boutique                 Wine Shop
# 22            Sandwich Place    Salon / Barbershop  Mediterranean Restaurant
# 23             Women's Store    Italian Restaurant       Sporting Goods Shop
# 24                  Wine Bar             Jazz Club                      Park
# 27               Pizza Place            Bagel Shop        Mexican Restaurant
# 28             Memorial Site         Boat or Ferry        Italian Restaurant
# 29                       Gym          Cocktail Bar               Pizza Place
# 30                       Spa                Bakery                 Bookstore
# 31                 Bookstore         Grocery Store        Mexican Restaurant
# 32                     Hotel        Sandwich Place       Sporting Goods Shop
# 33       Japanese Restaurant             Hotel Bar            Cosmetics Shop
# 34                 Juice Bar                   Gym               Pizza Place
# 35                  Wine Bar      Ramen Restaurant         Indian Restaurant
# 38            Clothing Store  Gym / Fitness Center              Cycle Studio
# 39        Spanish Restaurant            Restaurant                     Hotel
#
#             8th Most Common Venue     9th Most Common Venue  \
# 1             Dumpling Restaurant                    Bakery
# 6             American Restaurant                 Bookstore
# 8               French Restaurant                     Hotel
# 9             Japanese Restaurant             Deli / Bodega
# 10                 Cosmetics Shop                       Gym
# 11                  Deli / Bodega               Supermarket
# 12                 Cosmetics Shop               Coffee Shop
# 13                    Opera House                      Park
# 14                    Coffee Shop                       Spa
# 15                         Bakery                 Bookstore
# 16              French Restaurant                       Spa
# 17                    Art Gallery                   Theater
# 18             Chinese Restaurant         French Restaurant
# 19  Vegetarian / Vegan Restaurant               Coffee Shop
# 21                       Wine Bar                       Gym
# 22                 Ice Cream Shop               Yoga Studio
# 23                    Men's Store  Mediterranean Restaurant
# 24                   Cocktail Bar                 Speakeasy
# 27                          Hotel             Grocery Store
# 28                      Wine Shop              Cupcake Shop
# 29           Gym / Fitness Center        Italian Restaurant
# 30                           Café            Cosmetics Shop
# 31                      Gift Shop               Pizza Place
# 32            American Restaurant                    Bakery
# 33                    Coffee Shop                 Gastropub
# 34                   Dessert Shop       American Restaurant
# 35                           Café       Japanese Restaurant
# 38             Salon / Barbershop   New American Restaurant
# 39                 Sandwich Place               Coffee Shop
#
#     10th Most Common Venue
# 1     Cantonese Restaurant
# 6                 Beer Bar
# 8                      Spa
# 9       Mexican Restaurant
# 10            Cocktail Bar
# 11          Farmers Market
# 12                     Pub
# 13   Performing Arts Venue
# 14                Wine Bar
# 15     Sporting Goods Shop
# 16                     Bar
# 17                   Hotel
# 18            Burger Joint
# 19            Cocktail Bar
# 21        Greek Restaurant
# 22     Japanese Restaurant
# 23                   Hotel
# 24             Coffee Shop
# 27  Thrift / Vintage Store
# 28               BBQ Joint
# 29     American Restaurant
# 30           Grocery Store
# 31               Rock Club
# 32            Cocktail Bar
# 33    Gym / Fitness Center
# 34       French Restaurant
# 35       French Restaurant
# 38            Dessert Shop
# 39          Ice Cream Shop

# %% [markdown]
# #### Cluster 3

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 2, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 2    Washington Heights                  Café                Bakery
# 3                Inwood    Mexican Restaurant                Lounge
# 5        Manhattanville    Italian Restaurant    Mexican Restaurant
# 20      Lower East Side           Coffee Shop      Ramen Restaurant
# 26  Morningside Heights           Coffee Shop   American Restaurant
# 36           Tudor City                  Park    Mexican Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2      Mobile Phone Shop         Grocery Store    Spanish Restaurant
# 3                   Café           Pizza Place         Deli / Bodega
# 5     Seafood Restaurant                  Park           Coffee Shop
# 20           Pizza Place                  Café   Japanese Restaurant
# 26                  Park             Bookstore          Burger Joint
# 36                  Café      Greek Restaurant                 Hotel
#
#    6th Most Common Venue 7th Most Common Venue    8th Most Common Venue  \
# 2            Coffee Shop      Tapas Restaurant  New American Restaurant
# 3               Wine Bar   American Restaurant                   Bakery
# 5          Deli / Bodega           Supermarket             Burger Joint
# 20           Art Gallery                Bakery       Chinese Restaurant
# 26            Food Truck         Deli / Bodega             Tennis Court
# 36               Dog Run      Sushi Restaurant              Pizza Place
#
#         9th Most Common Venue 10th Most Common Venue
# 2   Latin American Restaurant                   Park
# 3                  Restaurant     Frozen Yogurt Shop
# 5          Spanish Restaurant            Bus Station
# 20               Cocktail Bar                   Park
# 26          Indian Restaurant      Outdoor Sculpture
# 36              Deli / Bodega         Sandwich Place

# %% [markdown]
# #### Cluster 4

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 3, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 37  Stuyvesant Town                   Bar                  Park
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 37            Playground     German Restaurant      Basketball Court
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 37        Baseball Field       Harbor / Marina          Cocktail Bar
#
#    9th Most Common Venue 10th Most Common Venue
# 37           Coffee Shop               Heliport

# %% [markdown]
# #### Cluster 5

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 4, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0  Marble Hill        Sandwich Place        Discount Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0           Coffee Shop           Yoga Studio            Steakhouse
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0       Supplement Shop         Shopping Mall    Seafood Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0        Tennis Stadium                    Gym

# %% [markdown]
# ##  Analyze Central Toronto Neighborhood and Results

# %%
TorontoCentral_venues.head()
# Out:
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0     Lawrence Park              43.728020              -79.388790
# 1     Lawrence Park              43.728020              -79.388790
# 2     Lawrence Park              43.728020              -79.388790
# 3  Davisville North              43.712751              -79.390197
# 4  Davisville North              43.712751              -79.390197
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 0            Lawrence Park Ravine       43.726963       -79.394382
# 1              Zodiac Swim School       43.728532       -79.382860
# 2  TTC Bus #162 - Lawrence-Donway       43.728026       -79.382805
# 3                   Sherwood Park       43.716551       -79.387776
# 4         Summerhill Market North       43.715499       -79.392881
#
#       Venue Category
# 0               Park
# 1        Swim School
# 2           Bus Line
# 3               Park
# 4  Food & Drink Shop

# %%
# one hot encoding
Toronto_onehot = pd.get_dummies(TorontoCentral_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Toronto_onehot['Neighborhood'] = TorontoCentral_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
Toronto_onehot = Toronto_onehot[fixed_columns]

# Toronto_onehot.head()

# %%
Toronto_grouped = Toronto_onehot.groupby('Neighborhood').mean().reset_index()
#Toronto_grouped

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
TorontoCentral_venues_sorted = pd.DataFrame(columns=columns)
TorontoCentral_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    TorontoCentral_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

TorontoCentral_venues_sorted.head(10)
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                         Davisville           Coffee Shop
# 1                                   Davisville North        Sandwich Place
# 2  Deer Park,Forest Hill SE,Rathnelly,South Hill,...           Coffee Shop
# 3                 Forest Hill North,Forest Hill West                 Trail
# 4                                      Lawrence Park           Swim School
# 5                         Moore Park,Summerhill East          Tennis Court
# 6                                 North Toronto West        Clothing Store
# 7                                           Roselawn                Garden
# 8                  The Annex,North Midtown,Yorkville        Sandwich Place
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0        Sandwich Place          Dessert Shop    Italian Restaurant
# 1                 Hotel        Breakfast Spot                   Gym
# 2                   Pub   American Restaurant            Sports Bar
# 3         Jewelry Store      Sushi Restaurant    Mexican Restaurant
# 4              Bus Line                  Park           Yoga Studio
# 5                  Park           Summer Camp            Playground
# 6           Coffee Shop           Yoga Studio    Salon / Barbershop
# 7           Yoga Studio          Dessert Shop        Ice Cream Shop
# 8           Coffee Shop                  Café           Pizza Place
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0            Pizza Place                  Café      Sushi Restaurant
# 1                   Park        Clothing Store     Food & Drink Shop
# 2  Vietnamese Restaurant   Fried Chicken Joint    Light Rail Station
# 3            Yoga Studio          Dessert Shop        History Museum
# 4           Dessert Shop                 Hotel        History Museum
# 5            Yoga Studio          Dessert Shop        History Museum
# 6             Bagel Shop    Chinese Restaurant          Dessert Shop
# 7                  Hotel        History Museum                   Gym
# 8    American Restaurant                  Park                   Pub
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0       Thai Restaurant        Farmers Market    Fried Chicken Joint
# 1          Dessert Shop        History Museum       Greek Restaurant
# 2          Liquor Store           Pizza Place             Restaurant
# 3                   Gym      Greek Restaurant           Gourmet Shop
# 4                   Gym      Greek Restaurant           Gourmet Shop
# 5                   Gym      Greek Restaurant           Gourmet Shop
# 6                 Diner  Fast Food Restaurant         Ice Cream Shop
# 7      Greek Restaurant          Gourmet Shop    Fried Chicken Joint
# 8          Liquor Store        History Museum         Cosmetics Shop

# %% [markdown]
# ###  Run *k*-means to cluster the Central Toronto neighborhood into 5 clusters

# %%
kclusters = 5

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 4, 3, 2, 0, 1, 0], dtype=int32)

# %%
# add clustering labels
TorontoCentral_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Toronto_merged = TorontoCentral_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
Toronto_merged = Toronto_merged.join(TorontoCentral_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

#manhattan_merged = manhattan_merged.drop(['Unnamed:0'], axis=1)
Toronto_merged.head() # check the last columns!
# Out:
#            Borough                Neighborhood   Latitude  Longitude  \
# 0  Central Toronto               Lawrence Park  43.728020 -79.388790
# 1  Central Toronto            Davisville North  43.712751 -79.390197
# 2  Central Toronto          North Toronto West  43.715383 -79.405678
# 3  Central Toronto                  Davisville  43.704324 -79.388790
# 4  Central Toronto  Moore Park,Summerhill East  43.689574 -79.383160
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               3           Swim School              Bus Line
# 1               0        Sandwich Place                 Hotel
# 2               0        Clothing Store           Coffee Shop
# 3               0           Coffee Shop        Sandwich Place
# 4               2          Tennis Court                  Park
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                  Park           Yoga Studio          Dessert Shop
# 1        Breakfast Spot                   Gym                  Park
# 2           Yoga Studio    Salon / Barbershop            Bagel Shop
# 3          Dessert Shop    Italian Restaurant           Pizza Place
# 4           Summer Camp            Playground           Yoga Studio
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                 Hotel        History Museum                   Gym
# 1        Clothing Store     Food & Drink Shop          Dessert Shop
# 2    Chinese Restaurant          Dessert Shop                 Diner
# 3                  Café      Sushi Restaurant       Thai Restaurant
# 4          Dessert Shop        History Museum                   Gym
#
#   9th Most Common Venue 10th Most Common Venue
# 0      Greek Restaurant           Gourmet Shop
# 1        History Museum       Greek Restaurant
# 2  Fast Food Restaurant         Ice Cream Shop
# 3        Farmers Market    Fried Chicken Joint
# 4      Greek Restaurant           Gourmet Shop

# %%
address = 'Central Toronto, Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Central Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Central Toronto are 43.653963, -79.387207.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Central Toronto venue clusters
# Examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %% [markdown]
# #### Cluster 1

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 1                                   Davisville North        Sandwich Place
# 2                                 North Toronto West        Clothing Store
# 3                                         Davisville           Coffee Shop
# 5  Deer Park,Forest Hill SE,Rathnelly,South Hill,...           Coffee Shop
# 8                  The Annex,North Midtown,Yorkville        Sandwich Place
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1                 Hotel        Breakfast Spot                   Gym
# 2           Coffee Shop           Yoga Studio    Salon / Barbershop
# 3        Sandwich Place          Dessert Shop    Italian Restaurant
# 5                   Pub   American Restaurant            Sports Bar
# 8           Coffee Shop                  Café           Pizza Place
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 1                   Park        Clothing Store     Food & Drink Shop
# 2             Bagel Shop    Chinese Restaurant          Dessert Shop
# 3            Pizza Place                  Café      Sushi Restaurant
# 5  Vietnamese Restaurant   Fried Chicken Joint    Light Rail Station
# 8    American Restaurant                  Park                   Pub
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 1          Dessert Shop        History Museum       Greek Restaurant
# 2                 Diner  Fast Food Restaurant         Ice Cream Shop
# 3       Thai Restaurant        Farmers Market    Fried Chicken Joint
# 5          Liquor Store           Pizza Place             Restaurant
# 8          Liquor Store        History Museum         Cosmetics Shop

# %% [markdown]
# #### Cluster 2

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 6     Roselawn                Garden           Yoga Studio
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 6          Dessert Shop        Ice Cream Shop                 Hotel
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 6        History Museum                   Gym      Greek Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 6          Gourmet Shop    Fried Chicken Joint

# %% [markdown]
# #### Cluster 3

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                  Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 4  Moore Park,Summerhill East          Tennis Court                  Park
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 4           Summer Camp            Playground           Yoga Studio
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 4          Dessert Shop        History Museum                   Gym
#
#   9th Most Common Venue 10th Most Common Venue
# 4      Greek Restaurant           Gourmet Shop

# %% [markdown]
# #### Cluster 4

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0  Lawrence Park           Swim School              Bus Line
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                  Park           Yoga Studio          Dessert Shop
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                 Hotel        History Museum                   Gym
#
#   9th Most Common Venue 10th Most Common Venue
# 0      Greek Restaurant           Gourmet Shop

# %% [markdown]
# #### Cluster 5

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4, Toronto_merged.columns[[1] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                          Neighborhood 1st Most Common Venue  \
# 7  Forest Hill North,Forest Hill West                 Trail
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 7         Jewelry Store      Sushi Restaurant    Mexican Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 7           Yoga Studio          Dessert Shop        History Museum
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 7                   Gym      Greek Restaurant           Gourmet Shop

# %% [markdown]
# ## Result Discussion and Recommendation <a name="results"></a>

# %% [markdown]
# ## Result Discussion
#
# Based on the outlined analysis methodology, we will discuss the results as follows:
#
# ### 1. Total number of venue comparison between Manhattan and Central Toronto:
#     (1) Both Manhattan and Central Toronto show similarities in large numbers of diverse venue in their neighborhoods, reflecting their leading business and cultural center status in their respective countries.
#     (2) However, based on individual neighborhood venue data comparison, Manhattan has order of magnitude more of total number of venue, reflecting that Manhattan has much more number of neighborhood (40 for Manhattan and 9 for Central Toronto) and much higher working and residential population than Central Toronto.
#     (3) Based on the above comparison, there should be good location options for new business office and family home in Central Toronto. However, the selection options in Central Toronto could still be much less than Manhattan since the total number of venue options in Central Toronto is much less than the total number of venue in Manhattan.
#
#
# ### 2. Venue ranking information and their implications:
#     (1) For Financial district in Manhattan, the top ranking venues include coffee shop, hotel, and various restaurants, reflecting those venues serving working and traveling populations. Will select new busienss office location options in Central Toronto with the similar venue ranking.
#
#     (2) For high-end residential neighborhood in Manhattan, such as Upper East Side next to famious New York Central Park, the top venues include restaurant, exhibit and art gallery, and fitness facilities. These venues are also preferred by the busienss manager for their new family home location optons in Toronto.
#
#     (3) To match the venue preference, the new business office location will clearly be at relatively small area of financial district in Central Toronto where there are high concentration of office buildings, hotels, restaurants and coffee shop.
#
#     (4) For family home location options in Central Toronto, the choices could be relatively hard to match Upper East Side neighborhood in Manhattan that are close to Park, musium and restaurants. Although downtown area in Central Toronto could offer good restaurant and musium venue, but downtown could be far away fro large park venue comparable to Manhattan Central Park. On the other hand, the large park venue in Toronto could be more available in a far distance areas from Toronto downtown and from restaurant and musium venues.
#
#
# ### 3. K-means venue clustering results and their implications:
#     (1) K-means venue clustering analysis provides consistent results with those from venue ranking analysis. It provides convincing confirmation regarding observations from the venue ranking analysis.
#
#     (2) In addition, the clustering results reveal that the neighborhood of Davisville North offers good venues of Park, grovery shopping and dancing and fitness facilities. Such venue availability could be suitable for new family home location in Central Toronto.

# %% [markdown]
# ## Recommendations:
#
# Based on the above result discussions, we will propose the following recommendations regarding potential location options in Central Toronto for US business manager to consider:
#     (1) For new business office in Central Toronto, the clear option is at the financial district of Central Toronto, with plenty venues of office building, hotel, and restaurants.
#     (2) For new family home, the potential location options could be in the neighborhood of Davisville North or Davisville, where there are revnues of park, grocery shopping,  restaurants and fitness facilities.
#
# ### Suggestions for further study:
#     (1) After presenting the project, need to solocit feedbacks from the US business manager and his company's decision makers.
#     (2) To verify and to evaluate location options, suggest to arrange visits to Central Toronto by the US business manager and his family.
#     (3) May need to expand this project to inlcude other important factors in location selection, such as cost and transportation convinince.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Based on data collection and analysis, this project provides detail evaluation of relocation options for US business manager for office and family home location selection.
#
# Although Toronto also offers large number of venue for business and family life, comparison to Manhattan in New York, there are still some limitations, especially for family home location considerations. There coudl be tradeoff considerations to balance the preference for various venues.
#
# While the report presents recommendations, it also suggests to further improve this study by getting feedbacks, arranging visits to Toronto, and to consider other important factors.
#
# With further iterative data analysis and evaluation, we believe that Toronto could offer very satisfactory options for both new business office and family home selection.
